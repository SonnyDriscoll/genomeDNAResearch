# 28     1311232223113432432421344332331112224422       1
# 29     3442212343311224232442243222342433211232       4
# ...                                         ...     ...
# 29970  2433222322432323222431412342322123212232       4
# 29971  3214231124312312214331344231324324243324       1
# 29972  2232132342312342432142132113443232132111       2
# 29973  2424311432432322434422432312424122432422       4
# 29974  1223231232234323433121332241442324334331       3
# 29975  3123312322332243323113243123213311311233       3
# 29976  2433141421132432232233112224222431242232       4
# 29977  1224231312324323224332232321323244233231       2
# 29978  4232142313332243142132212213232311243122       1
# 29979  3113232322133132431433133141432323223122       4
# 29980  4234231432432313243324331213234334232231       2
# 29981  2442143324232322343142112243243232112323       1
# 29982  2233321412233243123222332131131424423112       2
# 29983  1143321433233221232231132321333132222321       1
# 29984  4333144342232132122322224132143131212242       3
# 29985  2243223222132424223123121132322314223311       2
# 29986  3232433423143142132112431424333212323324       4
# 29987  2232213232242324321124332131323233324324       3
# 29988  4232322344122142232233243242132212211422       3
# 29989  3424332431321142212223311222133423224144       2
# 29990  4224323222224321314342221242213244232212       3
# 29991  3433322132223322312242132232442342232143       2
# 29992  3321123422433124423124322133433342423234       3
# 29993  1432241224314224332122331321323224332332       2
# 29994  2113211132332323222122223143121123123222       4
# 29995  3442322432123132321113322322434143223124       4
# 29996  4231224311331122233321122321124331234234       2
# 29997  2243222213322433341314122342332132412232       3
# 29998  1223311123322132423323114421422432112223       4
# 29999  2324233241223244232223221333212221332142       1
#
# [30000 rows x 4 columns]

# %%
input_X = df_geneDataSelect[['Variable1','Variable2','Variable3',]]
output_y = df_geneDataSelect['Output']

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(input_X, output_y, test_size=0.25, random_state=33)

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 3, min_samples_leaf = 5)
clf = clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-54d383baddb7> in <module>()
#       2
#       3 clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 3, min_samples_leaf = 5)
# ----> 4 clf = clf.fit(X_train, y_train)
#
# /Users/SonnyDriscoll1/anaconda/lib/python3.5/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     737             sample_weight=sample_weight,
#     738             check_input=check_input,
# --> 739             X_idx_sorted=X_idx_sorted)
#     740         return self
#     741
#
# /Users/SonnyDriscoll1/anaconda/lib/python3.5/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     120         random_state = check_random_state(self.random_state)
#     121         if check_input:
# --> 122             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     123             y = check_array(y, ensure_2d=False, dtype=None)
#     124             if issparse(X):
#
# /Users/SonnyDriscoll1/anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# /Users/SonnyDriscoll1/anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
from sklearn import metrics

def measure_performance(X, y, clf, show_accuracy=True, show_classification_report=True, show_confusion_matrix=True):
    y_pred = clf.predict(X)
    if show_accuracy:
        print("Accuracy:{0:.3f}".format(metrics.accuracy_score(y, y_pred)),"\n")

    if show_classification_report:
        print("Classification report")
        print(metrics.classification_report(y,y_pred),"\n")

    if show_confusion_matrix:
        print("Confusion matrix")
        print(metrics.confusion_matrix(y,y_pred),"\n")
        
# And call this method for the training data (display only accuracy)
measure_performance(X_test, y_test, clf) #show_classification_report=False, show_confusion_matrix=False)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-24-42905f0b7a01> in <module>()
#      15
#      16 # And call this method for the training data (display only accuracy)
# ---> 17 measure_performance(X_test, y_test, clf) #show_classification_report=False, show_confusion_matrix=False)
#      18
#      19
#
# <ipython-input-24-42905f0b7a01> in measure_performance(X, y, clf, show_accuracy, show_classification_report, show_confusion_matrix)
#       2
#       3 def measure_performance(X, y, clf, show_accuracy=True, show_classification_report=True, show_confusion_matrix=True):
# ----> 4     y_pred = clf.predict(X)
#       5     if show_accuracy:
#       6         print("Accuracy:{0:.3f}".format(metrics.accuracy_score(y, y_pred)),"\n")
#
# /Users/SonnyDriscoll1/anaconda/lib/python3.5/site-packages/sklearn/tree/tree.py in predict(self, X, check_input)
#     402         """
#     403
# --> 404         X = self._validate_X_predict(X, check_input)
#     405         proba = self.tree_.predict(X)
#     406         n_samples = X.shape[0]
#
# /Users/SonnyDriscoll1/anaconda/lib/python3.5/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
#     359         """Validate X whenever one tries to predict, apply, predict_proba"""
#     360         if self.tree_ is None:
# --> 361             raise NotFittedError("Estimator not fitted, "
#     362                                  "call `fit` before exploiting the model.")
#     363
#
# NotFittedError: Estimator not fitted, call `fit` before exploiting the model.

# %%
from sklearn.ensemble import RandomForestClassifier

clf1 = RandomForestClassifier(n_estimators=10, random_state=33)
clf1 = clf1.fit(X_train, y_train)

measure_performance(X_test, y_test, clf1) #show_classification_report=False, show_confusion_matrix=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-e431ce165d2f> in <module>()
#       2
#       3 clf1 = RandomForestClassifier(n_estimators=10, random_state=33)
# ----> 4 clf1 = clf1.fit(X_train, y_train)
#       5
#       6 measure_performance(X_test, y_test, clf1) #show_classification_report=False, show_confusion_matrix=False)
#
# /Users/SonnyDriscoll1/anaconda/lib/python3.5/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if issparse(X):
#
# /Users/SonnyDriscoll1/anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# /Users/SonnyDriscoll1/anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
from sklearn.neural_network import MLPClassifier

clf2 = MLPClassifier(solver='lbfgs', alpha=1e-5,
                    hidden_layer_sizes=(15), random_state=1)
clf2.fit(X_train, y_train)                         
MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto',
       beta_1=0.9, beta_2=0.999, early_stopping=False,
       epsilon=1e-08, hidden_layer_sizes=(5, 2), learning_rate='constant',
       learning_rate_init=0.001, max_iter=200, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
       solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
       warm_start=False)

predictions = clf2.predict(X_test)


#from sklearn.metrics import classification_report,confusion_matrix
#print(confusion_matrix(y_test,predictions))
#print(classification_report(y_test,predictions))


measure_performance(X_test, y_test, clf2) #show_classification_report=False, show_confusion_matrix=False)
# Out:
# Accuracy:0.265
#
# Classification report
#              precision    recall  f1-score   support
#
#           1       0.15      0.33      0.21      1233
#           2       0.33      0.64      0.43      2486
#           3       0.00      0.00      0.00      2488
#           4       0.00      0.00      0.00      1293
#
# avg / total       0.13      0.27      0.18      7500
#
#
# Confusion matrix
# [[ 405  828    0    0]
#  [ 902 1584    0    0]
#  [ 933 1555    0    0]
#  [ 456  837    0    0]]
# /Users/SonnyDriscoll1/anaconda/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.svm import SVC

svc_1 = SVC(kernel='linear', C=1)
clf3 = svc_1.fit(X_train, y_train)

#To show score clf.score(X_test, y_test) 
measure_performance(X_test, y_test, clf3)
# Out:
# Accuracy:0.172
#
# Classification report
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00      1233
#           2       0.00      0.00      0.00      2486
#           3       0.00      0.00      0.00      2488
#           4       0.17      1.00      0.29      1293
#
# avg / total       0.03      0.17      0.05      7500
#
#
# Confusion matrix
# [[   0    0    0 1233]
#  [   0    0    0 2486]
#  [   0    0    0 2488]
#  [   0    0    0 1293]]
# /Users/SonnyDriscoll1/anaconda/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
